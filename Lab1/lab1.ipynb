# %% [markdown]
# 1. Sử dụng bộ dữ liệu CIFAR 10. Có sử dụng dataloader hoặc các pp đọc dữ liệu khác của torch.
#
# 2. Phân tách thành 2 hàm chính: Hàm train(model, args), Hàm predict. Để thực huấn luyện và dự báo kết quả.
#
# 3. Sử dụng KNN với K= 5 or 7 để thực thi quá trình phân lớp ảnh. Theo 2 hàm train, predict đã phân tách ở trên.
#
# 4. Sử dụng model Liner Classifier để thực thi quá trình huấn luyện ở trên, loss softmax (có thể kết hợp kl và cross entropy)
#
# 5. Sử dụng SVM để huấn luyện với data ở trên kết hợp với SVM loss (slide)
#
# 6. Đưa ra bảng số liệu tổng hợp về các đánh giá accuracy, F1, và precision của 3 mô hình trên.
